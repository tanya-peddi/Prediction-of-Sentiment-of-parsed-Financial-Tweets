# %%
import pandas as pd

trial_data= pd.read_csv("C:/Users/Tanya Peddi/Desktop/Individual  Study/11k_WITH_ID_less_words_3.csv")
combo_list = pd.read_csv("C:/Users/Tanya Peddi/Desktop/Individual  Study/0-Couple-Semantics.csv")
positive_list =  open("C:/Users/Tanya Peddi/Desktop/Individual  Study/0-positive-words-McDonald.txt", "r")
negative_list = open("C:/Users/Tanya Peddi/Desktop/Individual  Study/0-negative-words-McDonald.txt","r")

# %%
trial_data
# Out:
#             id                                         Unnamed: 1  \
# 0          212                       tesla owners happy cars tsla
# 1          346  amazon received patent technology would bring ...
# 2          533  rt stocktwits happy new year everyone heres on...
# 3          571  everyone comments else aside twtr realtime pul...
# 4          761  final 24 hours save 3570 blowout holiday sale ...
# 5          809                              spy qqq aapl 2017 win
# 6         1023  rt sampp 500 weekly chart amp market breadth u...
# 7         1117  watch trump make twtr important ignore 2017 co...
# 8         1118  rt russellrhoads 2015 vs 2016 average closing ...
# 9         1146  heres daily inspiration want see get pumped up...
# 10        1284  rt goldmansachs video gs chief economist jan h...
# 11        1378  video gs chief economist jan hatzius drive 35 ...
# 12        1599                  microsoft well 2016 new year msft
# 13        2181  twitters top china executive leaves 8 months twtr
# 14        2342  apple expected make big upgrade release 10than...
# 15        2380    5 great media stocks 2017 cbs amc nflx sni foxa
# 16        2690  78 gain since election day best postelection d...
# 17        3401                   might sell simply valuation amzn
# 18        3612       5 ways find happiness really matters fb twtr
# 19        3671            2017 bulls dow theory side dia djia spy
# 20        3693  5 trade ideas tuesday endp ul dragonfly capita...
# 21        3753  14 quarters losses teslamotors turned profit c...
# 22        4066  cnbcfastmoney traders share 2017 stock picks a...
# 23        4114  50 inspirational quotes get studying harder ne...
# 24        4176                  bwld turn risky stock huge winner
# 25        4263  havent said aapl prob hit airpods 2 pair wont ...
# 26        4307  seems fair aapls 2016 aapl gained mkt cap 1st ...
# 27        4388  up nflx tonight first movie looks like must wa...
# 28        4479  real vs questionable traders learn spot matter...
# 29        4583  rt ophirgottlieb twitter china head kathy chen...
# ...        ...                                                ...
# 10990  1001443  major etfs alltime highs today spy iwm qqq dia...
# 10991  1001690  rt wallstjesus sweepers still bullish amd c to...
# 10992  1001724  dow stocks hitting alltime highs today aapl ba...
# 10993  1001740                   know take elon plus 3 month tsla
# 10994  1001741  dow closed alltime high 8th consecutive tradin...
# 10995  1001902  overbought rsi not necessarily bearish spx qqq...
# 10996  1001934  terrific tuesday market comes back higher high...
# 10997  1001943     overbought doesnt mean via jkrinskymkm spx qqq
# 10998  1002162  rt 52 week high dow 30 mmm aapl hd mcd cat trv...
# 10999  1002202  apple closes record high 5th time 6 sessions a...
# 11000  1002292  rt 361capital lg cap alltime highs jumps stock...
# 11001  1002374  quest explain altaba continues yahoo could pay...
# 11002  1002533                  rt cgrantwsj guys tsla worth much
# 11003  1002589                                      crazy goog fb
# 11004  1002626  heres twitter thinks investors missing busines...
# 11005  1003207  tesla mobileye buy range ahead earnings invest...
# 11006  1003462  video fully rolled ios live premium video twit...
# 11007  1003631    7 stocks accelerating earnings growth nflx amat
# 11008  1003698  2013 podcast jason asked markets today goog fb...
# 11009  1003771  stocks sampp500 up 24 feb 16 lows nothing stop...
# 11010  1003904  brianfires pavelsenor time almost broke alread...
# 11011  1003919  5 stocks likely benefit apple iphone 8 upgrade...
# 11012  1004067  rt richbtig video fully rolled ios live premiu...
# 11013  1004106  stocks near buy zone 3 growth stocks break pan...
# 11014  1004176  rt charliebilello sampp 500 45 trading days wi...
# 11015  1004180  oil up good growth hard find among crystalkimm...
# 11016  1004216  intc easily one powerful use stop losses ever ...
# 11017  1004250  intc real careful option trading turned 8 loss...
# 11018  1004412  sampp 500 45 trading days without 1 intraday m...
# 11019  1004624  sampp 500 etf hit 11th alltime high year today...
#
#        score.positive  score.negative  SA score
# 0                   1               0         1
# 1                   0               0         1
# 2                   1               0         1
# 3                   0               0         1
# 4                   1               0         1
# 5                   1               0         1
# 6                   0               0         1
# 7                   1               1         1
# 8                   1               2         1
# 9                   1               0         1
# 10                  0               0         1
# 11                  0               0         1
# 12                  0               0        -1
# 13                  0               0        -1
# 14                  0               0         1
# 15                  0               0         1
# 16                  3               0         1
# 17                  0               1        -1
# 18                  1               0         1
# 19                  0               0         1
# 20                  0               0         1
# 21                  1               1         1
# 22                  0               0         1
# 23                  1               0         1
# 24                  1               1         1
# 25                  0               0        -1
# 26                  1               0         1
# 27                  0               0         1
# 28                  0               1         1
# 29                  0               0        -1
# ...               ...             ...       ...
# 10990               1               0         1
# 10991               0               0         1
# 10992               1               0         1
# 10993               0               0         1
# 10994               0               1         1
# 10995               0               2        -1
# 10996               1               0         1
# 10997               0               1         1
# 10998               0               0        -1
# 10999               1               0         1
# 11000               1               0         1
# 11001               0               0        -1
# 11002               0               0        -1
# 11003               0               0        -1
# 11004               0               0         1
# 11005               1               0         1
# 11006               0               0         1
# 11007               0               0         1
# 11008               0               0         1
# 11009               0               0         1
# 11010               0               1        -1
# 11011               1               0         1
# 11012               0               0         1
# 11013               1               1         1
# 11014               0               0         1
# 11015               1               0         1
# 11016               1               1         1
# 11017               1               1         1
# 11018               0               0         1
# 11019               0               0         1
#
# [11020 rows x 5 columns]

# %%
positivel = list(positive_list)
negativel = list(negative_list)
positivelist = []
negativelist =[]
for item in positivel:
    item = item.replace("\n","")
    positivelist.append(item.lower())
for item2 in negativel:
    item2 = item2.replace("\n","")
    negativelist.append(item2.lower())

# %%
# creating new columns for positive and negative
trial_data['positive'] = 0
trial_data['negative'] = 0
trial_data['if_contains'] = 0
trial_data['changed_tweets']= trial_data.iloc[:,1]
changed_tweets_number = []
for i in range(0,74):
    if combo_list.iloc[i,2]=='okay':
        combo_list.iloc[i,2]=1
    else:
        combo_list.iloc[i,2]= 0

# %%
# checking if any of the tweets have any couplets in them
tweet_array = trial_data.iloc[:,1]
for j in range(0,74):
    word= ' ' + combo_list.iloc[j,0] + ' ' 
    # j in place of row 0
    i=0;
    for tweet in tweet_array:
        if word in tweet:
            trial_data.iloc[i,7] = word;
        i=i+1;
   # tweet_array = trial_data.iloc[:,1]
    i=0;
    word = ' ' + combo_list.iloc[j,1] + ' '
    #j in place of row 0
    for tweet in tweet_array:
        if trial_data.iloc[i,7]!=0:
            old_word = trial_data.iloc[i,7]
            split_data = tweet.split(old_word,1)[1]
            #print(old_word)
            if word in split_data:
                #print("before : " + tweet)                
                if combo_list.iloc[j,2] == 1:
                    #j in place of row 0                     
                    tweet =tweet.replace(old_word," ")
                    tweet =tweet.replace(word," okay ")
                    trial_data.iloc[i,8]= tweet 
                    changed_tweets_number.append(i)
                    #print("After : " + trial_data.iloc[i,8] + "tweet number : " + str(i) +"\n")
                else :
                    tweet = tweet.replace(old_word," ")
                    tweet = tweet.replace(word," notokay ")
                    trial_data.iloc[i,8]= tweet
                    changed_tweets_number.append(i)
                    #print("After : " + trial_data.iloc[i,8] + "tweet number : " + str(i) +"\n")
                
        i=i+1
    trial_data['if_contains']  = 0

# %%
#counting number of positive and negative words in each tweet
i=0   
count =0         
tweet_array = trial_data.iloc[:,8]
for tweet in tweet_array:
    words = tweet.split()
    #words = trial_data.iloc[6475,8].split()
    for word in words:
        #print(word)
        if word in positivelist:
            trial_data.iloc[i,5] = trial_data.iloc[i,5] + 1
            #print("positive word : " + word + "\n")
            #print(word + " positive i= " + str(i ))
            #a = (words[word] + " positive i= " + str(i ))
            #print(a)
        elif word in negativelist:
            trial_data.iloc[i,6] = trial_data.iloc[i,6] + 1
            #print("negative word : " + word + "\n")
            #a1 = (words[word] + " negative i= " + str(i ))
            #print(a1)
        else:
            continue
        
    i= i + 1

# %%
d1 = pd.DataFrame(trial_data)
d1.to_csv('C:/Users/Tanya Peddi/Desktop/Individual  Study/couplet_dataset.csv',encoding='utf-8')
